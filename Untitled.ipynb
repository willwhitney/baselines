# %%
import bokeh
from bokeh.plotting import figure, show, output_notebook
from bokeh.charts import Scatter, Line, color
from bokeh import palettes
from bokeh.layouts import row
import colorcet
output_notebook()

import numpy as np
import pandas as pd
import os
import math
import json
import time
from IPython.display import clear_output

colors = palettes.Paired12
basedirs = ['results',
            '/mnt/nyu/baselines/results']
# basedirs = ['/mnt/nyu/structure-experiments/results']

tooltips = [
    ('Experiment', '@experiment'),
#     ('Step', '@step'),
#     ('Loss', '@loss'),
#     ('Prior divergence', '@priordivergence'),
#     ('Transition divergence', '@transdivergence'),
]
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="36e515c5-1250-463f-89ed-703fa5cef859">Loading BokehJS ...</span>
#     </div>

# %%
def sparsify(steps, values, amount):
    if amount < 2: return steps, values
    sparse_steps = []
    sparse_values = []

    for i in range(min(len(steps), len(values))):
        if i % amount == 0:
            sparse_values.append(values[i])
            sparse_steps.append(steps[i])
    return np.array(sparse_steps), np.array(sparse_values)

# %%
def load_result_df(experiment, smoothing=1, max_points=500, upto=None, jitter=0):
    for basedir in basedirs:
        df = pd.DataFrame()
        try:
            path = os.path.join(basedir, experiment, 'results.json')
            f = open(path)
            json_lst = f.readlines()
            df = pd.DataFrame.from_records(map(json.loads, json_lst))
            
            if len(df) > 0:
                break
        except Exception as e:
            import traceback
#             traceback.print_exc()
#             print("Error in parsing experiment {} from basedir {}:".format(experiment, basedir), e)
            continue

    df['step'] = df['TimestepsSoFar']
    numeric_columns = list(df.columns)
    df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors="coerce")

    if upto is not None:
        df = pd.DataFrame(df.query("step<{}".format(upto)))
    
    for col in numeric_columns:
        df[col] = df[col].rolling(smoothing, center=True).mean()
        if jitter != 0 and col != 'step':
            df[col] = df[col] + np.random.randn(len(df[col])) * jitter
    
    for col in df:
        df["".join(col.split()).lower()] = df[col]
    df['experiment'] = pd.Series([experiment] * len(df), index=df.index)
    
    every_nth = max(int(len(df) / max_points), 1)
    return df.iloc[::every_nth, :]

def make_dataframe(results, **kwargs):
    data = pd.DataFrame()
    for experiment in results:
        single_df = load_result_df(experiment, **kwargs)
        data = data.append(single_df, ignore_index=True)
    return data

# %%
title = "curriculum"
networks = [
#     "curriculum",
    "curriculum_kl0.01",
#     "curriculum-walldeath",
    "curriculum_walldeath_kl0.01",
    "curriculum_probe",
#     "curriculum_walldeath_kl0.01_bigbuffers",
]

data = make_dataframe(networks, smoothing=1, max_points=1000)

spaced_palette = palettes.linear_palette(colorcet.rainbow, len(networks))

plots = []
for facet in ['EpAccuracy', 'EpRewMean', 'EpDifficulty']:
    plot = Line(data, x='step', y=facet,
                title=title + ", " + facet,
                color=color(columns='experiment', palette=spaced_palette),
                tools='pan,wheel_zoom,box_zoom,save,reset', 
                active_scroll="wheel_zoom",
                tooltips=tooltips,
                plot_height=300,
                legend='top_right',)
    plots.append(plot)
    show(row(children=[plot], responsive=True))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="52ad389b-7307-4d66-80e9-36adb54a8d4c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("52ad389b-7307-4d66-80e9-36adb54a8d4c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("52ad389b-7307-4d66-80e9-36adb54a8d4c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '52ad389b-7307-4d66-80e9-36adb54a8d4c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"464ff622-3751-4624-b592-6045e93e806d":{"roots":{"references":[{"attributes":{"plot":{"id":"8eb52936-26fb-4f2e-9079-79ea7122273d","subtype":"Chart","type":"Plot"},"ticker":{"id":"f812a7e7-d6f0-48cf-a2c8-4a6bac59d050","type":"BasicTicker"}},"id":"7e8cc14a-2b79-48bb-970e-fc3ddb7c7c66","type":"Grid"},{"attributes":{"children":[{"id":"8eb52936-26fb-4f2e-9079-79ea7122273d","subtype":"Chart","type":"Plot"}],"sizing_mode":"scale_width"},"id":"f7edc0da-183f-44a9-8965-335a385c1278","type":"Row"},{"attributes":{"label":{"value":"curriculum_walldeath_kl0.01"},"renderers":[{"id":"67345ce9-5745-4782-96a4-78f2ed402abf","type":"GlyphRenderer"}]},"id":"79f1c69f-4f91-48f3-ae85-e88522be76a4","type":"LegendItem"},{"attributes":{"callback":null,"plot":{"id":"8eb52936-26fb-4f2e-9079-79ea7122273d","subtype":"Chart","type":"Plot"},"tooltips":[["Experiment","@experiment
b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"70861850-61fa-46fc-9eb8-08f21afc7df4":{"roots":{"references":[{"attributes":{},"id":"a6bdaaca-787d-476b-94c7-f211b4bb3ca6","type":"BasicTickFormatter"},{"attributes":{},"id":"9e272475-a60a-47f0-8d94-5305d87015fc","type":"BasicTicker"},{"attributes":{"items":[{"id":"935e3206-7b64-434e-a2f5-5de334ce4191","type":"LegendItem"},{"id":"70d8a18c-5b9e-4db0-b2fb-9d539b85e3b8","type":"LegendItem"},{"id":"685921d6-4757-4afd-8e51-6e9cf238b369","type":"LegendItem"}],"plot":{"id":"e5caf983-9d39-439f-9aa9-2e17be88315e","subtype":"Chart","type":"Plot"}},"id":"21fd87fe-7041-44a4-b4be-5eea9184e3dc","type":"Legend"},{"attributes":{"plot":{"id":"e5caf983-9d39-439f-9aa9-2e17be88315e","subtype":"Chart","type":"Plot"}},"id":"f2b597d1-8ce7-463d-8c0e-e7da16ba0110","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":{"id":"f2b597d1-8ce7-463d-8c0e-e7da16ba0110","type":"WheelZoomTool"},"active_tap":"auto","tools":[{"id":"976ab8ac-f3fa-47bd-bb85-9ed88c5cfff8","type":"PanTool"},{"id":"f2b597d1-8ce7-463d-8c0e-e7da16ba0110","type":"WheelZoomTool"},{"id":"6fdb54e8-e935-46ec-a2e8-6883c75774a8","type":"BoxZoomTool"},{"id":"27b112fd-da99-4ae3-bb8d-1845a129b105","type":"SaveTool"},{"id":"50006b5d-5745-4bfc-9b10-1bcb0c857357","type":"ResetTool"},{"id":"a63906b5-36e9-4c4c-81bd-8b89b46a84f5","type":"HoverTool"}]},"id":"7151caf4-5b9e-4d12-b28e-a7ac9f2870b2","type":"Toolbar"},{"attributes":{"label":{"value":"curriculum_walldeath_kl0.01"},"renderers":[{"id":"1329b048-2e3f-40c0-ac88-31c135b39c70","type":"GlyphRenderer"}]},"id":"70d8a18c-5b9e-4db0-b2fb-9d539b85e3b8","type":"LegendItem"},{"attributes":{"plot":{"id":"e5caf983-9d39-439f-9aa9-2e17be88315e","subtype":"Chart","type":"Plot"}},"id":"27b112fd-da99-4ae3-bb8d-1845a129b105","type":"SaveTool"},{"attributes":{"overlay":{"id":"c44c2683-cef8-42bb-82bc-91510ffe0cfb","type":"BoxAnnotation"},"plot":{"id":"e5caf983-9d39-439f-9aa9-2e17be88315e","subtype":"Chart","type":"Plot"}},"id":"6fdb54e8-e935-46ec-a2e8-6883c75774a8","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"e5caf983-9d39-439f-9aa9-2e17be88315e","subtype":"Chart","type":"Plot"},"ticker":{"id":"9e272475-a60a-47f0-8d94-5305d87015fc","type":"BasicTicker"}},"id":"e6e16f65-6877-440a-aa85-80dc13ded6a4","type":"Grid"},{"attributes":{"line_color":{"value":"#b2c01a"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"eb06c82d-f27c-4c75-9082-c8fac475e0fb","type":"Line"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.01"},{"experiment":"curriculum_kl0.0 ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="04d1bb6e-dc64-403c-a5e3-918ef2afbeac"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("04d1bb6e-dc64-403c-a5e3-918ef2afbeac");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("04d1bb6e-dc64-403c-a5e3-918ef2afbeac");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '04d1bb6e-dc64-403c-a5e3-918ef2afbeac' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f4a1b78c-eb2e-4623-a221-c566d19d8e66":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"exper ...
