# %%
import bokeh
from bokeh.plotting import figure, show, output_notebook
from bokeh.charts import Scatter, Line, color
from bokeh import palettes
from bokeh.layouts import row
import colorcet
output_notebook()

import numpy as np
import pandas as pd
import os
import math
import json
import time
from IPython.display import clear_output

colors = palettes.Paired12
basedirs = ['results',
            '/mnt/nyu/baselines/results']
# basedirs = ['/mnt/nyu/structure-experiments/results']

tooltips = [
    ('Experiment', '@experiment'),
#     ('Step', '@step'),
#     ('Loss', '@loss'),
#     ('Prior divergence', '@priordivergence'),
#     ('Transition divergence', '@transdivergence'),
]
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="36e515c5-1250-463f-89ed-703fa5cef859">Loading BokehJS ...</span>
#     </div>

# %%
def sparsify(steps, values, amount):
    if amount < 2: return steps, values
    sparse_steps = []
    sparse_values = []

    for i in range(min(len(steps), len(values))):
        if i % amount == 0:
            sparse_values.append(values[i])
            sparse_steps.append(steps[i])
    return np.array(sparse_steps), np.array(sparse_values)

# %%
def load_result_df(experiment, smoothing=1, max_points=500, upto=None, jitter=0):
    for basedir in basedirs:
        df = pd.DataFrame()
        try:
            path = os.path.join(basedir, experiment, 'results.json')
            f = open(path)
            json_lst = f.readlines()
            df = pd.DataFrame.from_records(map(json.loads, json_lst))
            
            if len(df) > 0:
                break
        except Exception as e:
            import traceback
#             traceback.print_exc()
#             print("Error in parsing experiment {} from basedir {}:".format(experiment, basedir), e)
            continue

    df['step'] = df['TimestepsSoFar']
    numeric_columns = list(df.columns)
    df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors="coerce")

    if upto is not None:
        df = pd.DataFrame(df.query("step<{}".format(upto)))
    
    for col in numeric_columns:
        df[col] = df[col].rolling(smoothing, center=True).mean()
        if jitter != 0 and col != 'step':
            df[col] = df[col] + np.random.randn(len(df[col])) * jitter
    
    for col in df:
        df["".join(col.split()).lower()] = df[col]
    df['experiment'] = pd.Series([experiment] * len(df), index=df.index)
    
    every_nth = max(int(len(df) / max_points), 1)
    return df.iloc[::every_nth, :]

def make_dataframe(results, **kwargs):
    data = pd.DataFrame()
    for experiment in results:
        single_df = load_result_df(experiment, **kwargs)
        data = data.append(single_df, ignore_index=True)
    return data

# %%
title = "curriculum"
networks = [
#     "curriculum",
    "curriculum_kl0.01",
#     "curriculum-walldeath",
    "curriculum_walldeath_kl0.01",
    "curriculum_probe",
#     "curriculum_walldeath_kl0.01_bigbuffers",
]

data = make_dataframe(networks, smoothing=1, max_points=1000)

spaced_palette = palettes.linear_palette(colorcet.rainbow, len(networks))

plots = []
for facet in ['EpAccuracy', 'EpRewMean', 'EpDifficulty']:
    plot = Line(data, x='step', y=facet,
                title=title + ", " + facet,
                color=color(columns='experiment', palette=spaced_palette),
                tools='pan,wheel_zoom,box_zoom,save,reset', 
                active_scroll="wheel_zoom",
                tooltips=tooltips,
                plot_height=300,
                legend='top_right',)
    plots.append(plot)
    show(row(children=[plot], responsive=True))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4e9c0cc1-342d-4ef7-a7c8-e75532cc973d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4e9c0cc1-342d-4ef7-a7c8-e75532cc973d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4e9c0cc1-342d-4ef7-a7c8-e75532cc973d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4e9c0cc1-342d-4ef7-a7c8-e75532cc973d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1c9b2de1-fec1-4bf6-8bfd-8bf84588874f":{"roots":{"references":[{"attributes":{"axis_label":"EpAccuracy","formatter":{"id":"5acb4b84-0380-4bfd-868a-f229fb0b1f7c","type":"BasicTickFormatter"},"plot":{"id":"351620a0-e93b-49cf-82df-f3ad764d7051","subtype":"Chart","type":"Plot"},"ticker":{"id":"463c0cc4-501a-4adb-ad0a-24fc2a52254c","type":"BasicTicker"}},"id":"a8c895f8-3e48-4547-96ab-fb8f8016ab30","type":"LinearAxis"},{"attributes":{},"id":"cf7cefcf-86b2-4887-9618-7827964ee87e","type":"LinearScale"},{"attributes":{"plot":{"id":"351620a0-e93b-49cf-82df-f3ad764d7051","subtype":"Chart","type":"Plot"}},"id":"3acab68b-cd2d-4102-9db2-97efe4b6c677","type":"PanTool"},{"attributes":{"plot":null,"text":"curriculum, EpAccuracy"},"id":"18125fbf-3eca-4517-9674-a121c5b29422","type":"Title"},{"attributes":{},"id":"f395cff7-545d-484e-97b5-115129df679a","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"351620a0-e93b-49cf-82df-f3ad764d7051","subtype":"Chart","type":"Plot"},"ticker":{"id":"463c0cc4-501a-4adb-ad0a-24fc2a52254c","type":"BasicTicker"}},"id":"bc66622c-7863-445f-b8b4-a34d8157757a","type":"Grid"},{"attributes":{"callback":null,"end":14493078.6,"start":-1314288.6},"id":"4d39947a-9683-46ea-bf6f-a4aa98abe507","type":"Range1d"},{"attributes":{"plot":{"id":"351620a0-e93b-49cf-82df-f3ad764d7051","subtype":"Chart","type":"Plot"}},"id":"875c9643-c612-4f0c-817b-e66791fcf872","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"351620a0-e93b-49cf-82df-f3ad764d7051","subtype":"Chart","type":"Plot"},"ticker":{"id":"f395cff7-545d-484e-97b5-115129df679a","type":"BasicTicker"}},"id":"e4006f05-a5e8-4e44-b30c-434374e66bdd","type":"Grid"},{"attributes":{"line_color":{"value":"#0034f8"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"1714bf7b-550b-40a7-aec4-d80d2c2baeb2","type":"Line"},{"attributes":{"below":[{"id":"ab8257fa-5235-4f90-b7e7-67319693b103","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"a8c895f8-3e48-4547-96ab-fb8f8016ab30","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"b2025eb5-430a-4207-91e3-cebf6ff3c20a","type":"BoxAnnotation"},{"id":"a4a60188-54e4-4082-ac75-ac0562889967","type":"GlyphRenderer"},{"id":"d20df28e-79fd-46c7-92eb-1564d42b71e1","type":"GlyphRenderer"},{"id":"ff24b4ce-019c-4471-aadc-b35efae8f90f","type":"GlyphRenderer"},{"id":"46135eb4-d282-4dcc-9891-05b7121453fc","type":"Legend"},{"id":"ab8257fa-5235-4f90-b7e7-67319693b103","type":"LinearAxis"},{"id":"a8c895f8-3e48-4547-96ab-fb8f8016ab30","type":"LinearAxis"},{"id":"e4006f05-a5e8-4e44-b30c-434374e66bdd","type":"Grid"},{"id":"bc66622c-7863-445f-b8b4-a34d8157757a","type":"Grid"}],"sizing_mode":"scale_width","title":{"id":"18125fbf-3eca-4517-9674-a121c5b29422","type":"Title"},"tool_events":{"id":"b28fa109-8439-4f73-b5f2-a425b57ea26a","type":"ToolEvents"},"toolbar":{"id":"e2fd052b-0c8b-4145-9558-963a631f9d23","type":"Toolbar"},"x_range":{"id":"4d39947a-9683-46ea-bf6f-a4aa98abe507","type":"Range1d"},"x_scale":{"id":"cf7cefcf-86b2-4887-9618-7827964ee87e","type":"LinearScale"},"y_range":{"id":"98c530d2-af6a-4a6d-b3a4-f5b71a17f596","type":"Range1d"},"y_scale":{"id":"5e9365e2-c502-499a-9633-8dbecd77b64c","type":"LinearScale"}},"id":"351620a0-e93b-49cf-82df-f3ad764d7051","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"1604613d-ae38-49a3-b069-7d4ca49e7f4e","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"47e1ac1c-088b-4ee4-b046-2f2d28d821c3","type":"ColumnDataSource"},"glyph":{"id":"1714bf7b-550b-40a7-aec4-d80d2c2baeb2","type":"Line"},"hover_glyph":null,"muted_glyph":null},"id":"a4a60188-54e4-4082-ac75-ac0562889967","type":"GlyphRenderer"},{"attributes":{},"id":"463c0cc4-501a-4adb-ad0a-24fc2a52254c","type":"BasicTicker"},{"attributes":{},"id":"5acb4b84-0380-4bfd-868a-f229fb0b1f7c","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#b2c01a"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"93dfe7e3-bca3-458a-a700-0a1a3d5a8 ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e64db05c-91f4-4cf0-b8b9-ad8dcd1cad8b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e64db05c-91f4-4cf0-b8b9-ad8dcd1cad8b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e64db05c-91f4-4cf0-b8b9-ad8dcd1cad8b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e64db05c-91f4-4cf0-b8b9-ad8dcd1cad8b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1ca33ce6-722a-4ec9-b9ea-a0357251bf73":{"roots":{"references":[{"attributes":{"children":[{"id":"05244904-529e-44e0-ae97-932a4ba8e14b","subtype":"Chart","type":"Plot"}],"sizing_mode":"scale_width"},"id":"a1f0ca05-51f4-4d0d-a795-5cdfb7ab83ff","type":"Row"},{"attributes":{"dimension":1,"plot":{"id":"05244904-529e-44e0-ae97-932a4ba8e14b","subtype":"Chart","type":"Plot"},"ticker":{"id":"3566885d-7dd1-4c97-8cf2-cf7ad17cb6eb","type":"BasicTicker"}},"id":"19f4ba10-794f-4f1c-bf17-08822791558f","type":"Grid"},{"attributes":{},"id":"756e5259-7951-4041-bbc7-f3963a3d9336","type":"LinearScale"},{"attributes":{},"id":"ef52810b-1279-45a4-93b4-03ef64ef2d98","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"679ce5c8-ea51-4f45-947f-81706be5fa67","type":"BoxAnnotation"},"plot":{"id":"05244904-529e-44e0-ae97-932a4ba8e14b","subtype":"Chart","type":"Plot"}},"id":"261394f1-766e-456f-be80-9e4257350fbe","type":"BoxZoomTool"},{"attributes":{},"id":"af1eb40f-9801-46f6-bbee-4323b2897c74","type":"BasicTickFormatter"},{"attributes":{"callback":null,"plot":{"id":"05244904-529e-44e0-ae97-932a4ba8e14b","subtype":"Chart","type":"Plot"},"tooltips":[["Experiment","@experiment"]]},"id":"c7a0594f-46ba-4a01-9394-d4e8c2ee2e24","type":"HoverTool"},{"attributes":{"line_color":{"value":"#0034f8"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"afd76240-a11c-4db6-afd3-a902dac8925d","type":"Line"},{"attributes":{"line_color":{"value":"#ff2a00"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"95b23dbd-48ba-4d58-8255-d5c936a021e8","type":"Line"},{"attributes":{"plot":{"id":"05244904-529e-44e0-ae97-932a4ba8e14b","subtype":"Chart","type":"Plot"}},"id":"2ec83397-ff66-4efb-9824-c1e6c3c9fe6b","type":"WheelZoomTool"},{"attributes":{"callback":null,"end":1.9347285156249994,"start":-9.588927734374995},"id":"98462717-2e40-459d-95e3-a4a0a0bb7c76","type":"Range1d"},{"attributes":{},"id":"d1c9677b-6c3a-4fb0-91d3-541e88b1c91f","type":"BasicTicker"},{"attributes":{"callback":null,"end":14493078.6,"start":-1314288.6},"id":"ae1b72a1-d887-4da7-b9be-29cd8e8be4b5","type":"Range1d"},{"attributes":{"data_source":{"id":"17e60dc9-15d7-4755-a56e-6b25c499f45e","type":"ColumnDataSource"},"glyph":{"id":"3f5ca69e-9ba0-46c1-b781-75d6673186d0","type":"Line"},"hover_glyph":null,"muted_glyph":null},"id":"5eed85b9-0fcb-45f3-acae-a8f777d85e2b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_walldeath_kl0.01"},{"experiment":"curriculum_wall ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a601ccc3-5f1f-456e-bd87-d0d9ec9ea1f5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a601ccc3-5f1f-456e-bd87-d0d9ec9ea1f5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a601ccc3-5f1f-456e-bd87-d0d9ec9ea1f5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a601ccc3-5f1f-456e-bd87-d0d9ec9ea1f5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c89c3922-6481-44a7-9e68-dfc1ff5cb317":{"roots":{"references":[{"attributes":{"line_color":{"value":"#0034f8"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"87579f7e-9b9d-4c23-8842-cd369f617acc","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"6d98abf5-0625-4ee4-9ae1-1145b48c4a69","subtype":"Chart","type":"Plot"},"ticker":{"id":"f5b2d3b7-1433-4964-b627-fc652afcd7de","type":"BasicTicker"}},"id":"6271e459-22ce-4d2c-ba02-248b94c3b70f","type":"Grid"},{"attributes":{"plot":{"id":"6d98abf5-0625-4ee4-9ae1-1145b48c4a69","subtype":"Chart","type":"Plot"}},"id":"3f348976-6868-4673-83c8-5bdb20a9d043","type":"WheelZoomTool"},{"attributes":{"children":[{"id":"6d98abf5-0625-4ee4-9ae1-1145b48c4a69","subtype":"Chart","type":"Plot"}],"sizing_mode":"scale_width"},"id":"67b936b1-9abe-4e52-a4a8-a0a7d8bc990c","type":"Row"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"},{"experiment":"curriculum_probe"}],"experiment":["curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe","curriculum_probe"],"x_values":{"__ndarray__":"...","dtype":"float64","shape":[49]},"y_values":{"__ndarray__":"...","dtype":"float64","shape":[49]}}},"id":"4395e7f5-70b9-43fa-a0df-9497f81db0d3","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_d ...
